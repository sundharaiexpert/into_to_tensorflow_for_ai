# %% [markdown]
# <a href="https://colab.research.google.com/github/sundharaiexpert/into_to_tensorflow_for_ai/blob/main/Intro_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello welcome to Google Colab")
# Out:
# hello welcome to Google Colab

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.7.0

# %%
from numpy.core.fromnumeric import shape
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 375ms/step - loss: 1.4595
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2841
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1433
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0298
# Epoch 5/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9379
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8629
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8013
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7504
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7078
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6720
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6414
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6150
# ...

# %%
# Make a prediction
print(model.predict([10.0]))
# Out:
# [[18.986189]]

# %%
# Train the model
model.fit(xs, ys, epochs=600)
# Out:
# Epoch 1/600
# 1/1 [==============================] - 0s 38ms/step - loss: 2.1945e-05
# Epoch 2/600
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1495e-05
# Epoch 3/600
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1053e-05
# Epoch 4/600
# 1/1 [==============================] - 0s 5ms/step - loss: 2.0620e-05
# Epoch 5/600
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0196e-05
# Epoch 6/600
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9781e-05
# Epoch 7/600
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9375e-05
# Epoch 8/600
# 1/1 [==============================] - 0s 6ms/step - loss: 1.8977e-05
# Epoch 9/600
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8587e-05
# Epoch 10/600
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8206e-05
# Epoch 11/600
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7832e-05
# Epoch 12/600
# ...

# %%
 # Make a prediction after 600 epochs
print(model.predict([10.0]))
# Out:
# [[18.999971]]
